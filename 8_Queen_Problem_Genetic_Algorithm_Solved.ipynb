# %% [markdown]
# <a href="https://colab.research.google.com/github/parisairam/learning/blob/master/8_Queen_Problem_Genetic_Algorithm_Solved.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class BoardPosition:
	def __init__(self):
		self.sequence = None
		self.fitness = None
		self.survival = None
	def setSequence(self, val):
		self.sequence = val
	def setFitness(self, fitness):
		self.fitness = fitness
	def setSurvival(self, val):
		self.survival = val
	def getAttr(self):
		return {'sequence':sequence, 'fitness':fitness, 'survival':survival}

def generateChromosome():
	# randomly generates a sequence of board states.
	global nQueens
	init_distribution = np.arange(nQueens)
	np.random.shuffle(init_distribution)
	return init_distribution

def generatePopulation(population_size = 100):
	global POPULATION

	POPULATION = population_size

	population = [BoardPosition() for i in range(population_size)]
	for i in range(population_size):
		population[i].setSequence(generateChromosome())
		population[i].setFitness(fitness(population[i].sequence))

	return population

def fitness(chromosome = None):
  clashes = 0
  row_col_clashes = abs(len(chromosome) - len(np.unique(chromosome)))
  clashes += row_col_clashes

	# calculate diagonal clashes
  for i in range(len(chromosome)):
    for j in range(len(chromosome)):
      if ( i != j):
        dx = abs(i-j)
        dy = abs(chromosome[i] - chromosome[j])
        if(dx == dy):
          clashes += 1


  return 28 - clashes

def getParent():
	globals()	
	parent1, parent2 = None, None
	# parent is decided by random probability of survival.
	# since the fitness of each board position is an integer >0, 
	# we need to normaliza the fitness in order to find the solution
	
	summation_fitness = np.sum([x.fitness for x in population])
	for each in population:
		each.survival = each.fitness/(summation_fitness*1.0)

	while True:
		parent1_random = np.random.rand()
		parent1_rn = [x for x in population if x.survival <= parent1_random]
		try:
			parent1 = parent1_rn[0]
			break
		except:
			pass

	while True:
		parent2_random = np.random.rand()
		parent2_rn = [x for x in population if x.survival <= parent2_random]
		try:
			t = np.random.randint(len(parent2_rn))
			parent2 = parent2_rn[t]
			if parent2 != parent1:
				break
			else:
				print("equal parents")
				continue
		except:
			print("exception")
			continue

	if parent1 is not None and parent2 is not None:
		return parent1, parent2
	else:
		sys.exit(-1)
  
def reproduce_crossover(parent1, parent2):
	globals()
	n = len(parent1.sequence)
	c = np.random.randint(n, size=1)
	child = BoardPosition()
	child.sequence = []
	child.sequence.extend(parent1.sequence[0:c])
	child.sequence.extend(parent2.sequence[c:])
	child.setFitness(fitness(child.sequence))
	return child

def mutate(child):
	"""	
	- according to genetic theory, a mutation will take place
	when there is an anomaly during cross over state
	- since a computer cannot determine such anomaly, we can define 
	the probability of developing such a mutation 
	"""
	if child.survival < MUTATE:
		c = np.random.randint(8)
		child.sequence[c] = np.random.randint(8)
	return child

def GA(iteration):
	print(" #"*10 ,"Executing Genetic  generation : ", iteration , " #"*10)
	globals()
	newpopulation = []
	for i in range(len(population)):
		parent1, parent2 = getParent()
		# print "Parents generated : ", parent1, parent2

		child = reproduce_crossover(parent1, parent2)

		if(MUTATE_FLAG):
			child = mutate(child)

		newpopulation.append(child)
	return newpopulation

def stop():
	globals()
	# print population[0], " printing population[0]"
	fitnessvals = [pos.fitness for pos in population]
	if STOP_CTR in fitnessvals:
		return True
	if MAX_ITER == iteration:
		return True
	return False



population = generatePopulation(1000)

print("POPULATION size : ", population)

iteration = 0;
while not stop():
	# keep iteratin till  you find the best position
	population = GA(iteration)
	iteration +=1 

print("Iteration number : ", iteration)
for each in population:
	if each.fitness == 28:
		print(each.sequence)
# Out:
# POPULATION size :  [<__main__.BoardPosition object at 0x7f1df3113550>, <__main__.BoardPosition object at 0x7f1df31602e8>, <__main__.BoardPosition object at 0x7f1df3128f98>, <__main__.BoardPosition object at 0x7f1df312d160>, <__main__.BoardPosition object at 0x7f1df312d208>, <__main__.BoardPosition object at 0x7f1df312d0b8>, <__main__.BoardPosition object at 0x7f1df31df048>, <__main__.BoardPosition object at 0x7f1df31df0b8>, <__main__.BoardPosition object at 0x7f1df31df0f0>, <__main__.BoardPosition object at 0x7f1df31df128>, <__main__.BoardPosition object at 0x7f1df31df160>, <__main__.BoardPosition object at 0x7f1df31df198>, <__main__.BoardPosition object at 0x7f1df31df1d0>, <__main__.BoardPosition object at 0x7f1df31df208>, <__main__.BoardPosition object at 0x7f1df31df240>, <__main__.BoardPosition object at 0x7f1df31df278>, <__main__.BoardPosition object at 0x7f1df31df2b0>, <__main__.BoardPosition object at 0x7f1df31df2e8>, <__main__.BoardPosition object at 0x7f1df31df320>, <__main__.BoardPosition object at 0x7f1df31df358>, <__main__.BoardPosition object at 0x7f1df31df390>, <__main__.BoardPosition object at 0x7f1df31df3c8>, <__main__.BoardPosition object at 0x7f1df31df400>, <__main__.BoardPosition object at 0x7f1df31df438>, <__main__.BoardPosition object at 0x7f1df31df470>, <__main__.BoardPosition object at 0x7f1df31df4a8>, <__main__.BoardPosition object at 0x7f1df31df4e0>, <__main__.BoardPosition object at 0x7f1df31df518>, <__main__.BoardPosition object at 0x7f1df31df550>, <__main__.BoardPosition object at 0x7f1df31df588>, <__main__.BoardPosition object at 0x7f1df31df5c0>, <__main__.BoardPosition object at 0x7f1df31df5f8>, <__main__.BoardPosition object at 0x7f1df31df630>, <__main__.BoardPosition object at 0x7f1df31df668>, <__main__.BoardPosition object at 0x7f1df31df6a0>, <__main__.BoardPosition object at 0x7f1df31df6d8>, <__main__.BoardPosition object at 0x7f1df31df710>, <__main__.BoardPosition object at 0x7f1df31df748>, <__main__.BoardPosition object at 0x7f1df31df780>, <__main__.BoardPosition object at 0x7f1df31df7b8>, <__main__.BoardPosition object at 0x7f1df31df7f0>, <__main__.BoardPosition object at 0x7f1df31df828>, <__main__.BoardPosition object at 0x7f1df31df860>, <__main__.BoardPosition object at 0x7f1df31df898>, <__main__.BoardPosition object at 0x7f1df31df8d0>, <__main__.BoardPosition object at 0x7f1df31df908>, <__main__.BoardPosition object at 0x7f1df31df940>, <__main__.BoardPosition object at 0x7f1df31df978>, <__main__.BoardPosition object at 0x7f1df31df9b0>, <__main__.BoardPosition object at 0x7f1df31df9e8>, <__main__.BoardPosition object at 0x7f1df31dfa20>, <__main__.BoardPosition object at 0x7f1df31dfa58>, <__main__.BoardPosition object at 0x7f1df31dfa90>, <__main__.BoardPosition object at 0x7f1df31dfac8>, <__main__.BoardPosition object at 0x7f1df31dfb00>, <__main__.BoardPosition object at 0x7f1df31dfb38>, <__main__.BoardPosition object at 0x7f1df31dfb70>, <__main__.BoardPosition object at 0x7f1df31dfba8>, <__main__.BoardPosition object at 0x7f1df31dfbe0>, <__main__.BoardPosition object at 0x7f1df31dfc18>, <__main__.BoardPosition object at 0x7f1df31dfc50>, <__main__.BoardPosition object at 0x7f1df31dfc88>, <__main__.BoardPosition object at 0x7f1df31dfcc0>, <__main__.BoardPosition object at 0x7f1df31dfcf8>, <__main__.BoardPosition object at 0x7f1df31dfd30>, <__main__.BoardPosition object at 0x7f1df31dfd68>, <__main__.BoardPosition object at 0x7f1df31dfda0>, <__main__.BoardPosition object at 0x7f1df31dfdd8>, <__main__.BoardPosition object at 0x7f1df31dfe10>, <__main__.BoardPosition object at 0x7f1df31dfe48>, <__main__.BoardPosition object at 0x7f1df31dfe80>, <__main__.BoardPosition object at 0x7f1df31dfeb8>, <__main__.BoardPosition object at 0x7f1df31dfef0>, <__main__.BoardPosition object at 0x7f1df31dff28>, <__main__.BoardPosition object at 0x7f1df31dff60>, <__main__.BoardPosition object at 0x7f1df31dff98>, <__main__.BoardPosition object at 0x7f1df31dffd0>, <__main__.BoardPosition object at 0x7f1df3136048>, <_ ...
# Iteration number :  0
# [5 2 6 1 3 7 0 4]
